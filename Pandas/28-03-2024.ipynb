# %% [markdown]
# #### Matplotlib and Pandas

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./data/data.csv")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
import mplcursors

plt.figure(figsize=(10, 8))
box_plot = sns.boxplot(data=df, x="IncomeGroup", y="InternetUsers")
mplcursors.cursor(hover=True)
# plt.legend(df["BirthRate"])
# plt.legend(df["BirthRate"], loc="upper left", bbox_to_anchor=(0.5, 0.25), ncol=3)
plt.show()

# %%
import mplcursors
box_plot = sns.boxplot(data=df, x = df["BirthRate"][:6], y="InternetUsers")
mplcursors.cursor(hover=True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
